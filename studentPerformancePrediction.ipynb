# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#load the data
data=pd.read_csv('student-mat.csv', sep=';')
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
#feature selection
data=data[["G1","G2","G3","studytime","failures","absences"]]

# %%
#print(data)

# %%
#reorder data to have the x and y
x=np.array(data.drop(["G3"],1))
y=np.array(data["G3"])
#print(x)
# Out:
# C:\Users\BENAIAH\AppData\Local\Temp/ipykernel_21268/2288796523.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   x=np.array(data.drop(["G3"],1))

# %%
#split the data
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#fn to calculate grade
def getGrade(s):
    if s<=35:
        print(f"Score: {s} , Grade is F")
    elif s <=45:
        print(f"Score: {s} , Grade is D")
    elif s <=65:
        print(f"Score: {s} , Grade is C")
    elif s <=85:
        print(f"Score: {s} , Grade is B")
    else:
        print(f"Score: {s} , Grade is A")

# %%
#prediction
result=model.predict(x_test)

# %%
# G1 = input("Input G1 score: ")
# G2 = input("Input G2 score: ")  
# studytime = input("Input studytime: ")
# fail = input("Input number of failures: ") 
# absences = input("Input number of absences: ")

# %%
#res=model.predict([[G1,G2,studytime,fail,absences]])

# %%
#getGrade(res[0])

# %%
for i in range(len(result)):
    getGrade(result[i])
# Out:
# Score: 15.133613716059951 , Grade is F
# Score: 15.035436836643658 , Grade is F
# Score: 8.575266925317475 , Grade is F
# Score: 9.734216115765989 , Grade is F
# Score: 9.136195761287807 , Grade is F
# Score: 7.969270415902816 , Grade is F
# Score: 10.066738498897537 , Grade is F
# Score: 12.80488520646547 , Grade is F
# Score: -0.6864735298646287 , Grade is F
# Score: 3.732653354906451 , Grade is F
# Score: 6.458877008222935 , Grade is F
# Score: 12.946921610885827 , Grade is F
# Score: 8.775457910957348 , Grade is F
# Score: 6.102953087000174 , Grade is F
# Score: 8.570375847496495 , Grade is F
# Score: 19.564476833861512 , Grade is F
# Score: 7.929472670314661 , Grade is F
# Score: 14.838029226797378 , Grade is F
# Score: 14.097219645419354 , Grade is F
# Score: 11.067325675396134 , Grade is F
# Score: 12.944659611431868 , Grade is F
# Score: 18.620314713802532 , Grade is F
# Score: 9.312084982461643 , Grade is F
# Score: 11.706121150550578 , Grade is F
# ...
